# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from table_diffusion import *

# %%
df = pd.read_csv('/Users/vikramvelankar/Downloads/diabetes.csv')
# df.drop(columns='id',inplace=True,axis=1)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
df1 = df[df['Outcome'] == 1]

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
tds = TableDiffusion_Synthesiser(cuda = False)

# %%
tds.fit(df1,discrete_columns=['Outcome'])
# Out:
# /Users/vikramvelankar/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:2590: UserWarning: n_quantiles (1000) is greater than the total number of samples (268). n_quantiles is set to n_samples.
#   warnings.warn(
# /Users/vikramvelankar/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:2590: UserWarning: n_quantiles (1000) is greater than the total number of samples (268). n_quantiles is set to n_samples.
#   warnings.warn(
# /Users/vikramvelankar/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:2590: UserWarning: n_quantiles (1000) is greater than the total number of samples (268). n_quantiles is set to n_samples.
#   warnings.warn(
# /Users/vikramvelankar/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:2590: UserWarning: n_quantiles (1000) is greater than the total number of samples (268). n_quantiles is set to n_samples.
#   warnings.warn(
# ...

# %%
results = tds.sample(n=232)#551824

# %%
results.to_csv('/Users/vikramvelankar/Desktop/URE/gen5.csv')

# %%
results

# %%
results['Outcome'].value_counts()

# %%
res_arr = results.iloc[:,:-1].to_numpy()

# %%
res_arr

# %%
orig_arr = df.iloc[:,:-1].to_numpy()

# %%
from scipy.stats import kstest, ks_2samp

# %%
samp = ks_2samp(orig_arr, res_arr)
