# %%
from visualisations import * 
import pandas as pd
import numpy as np
# Out:
# /Users/vikramvelankar/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df1 = pd.read_csv('/Users/vikramvelankar/Desktop/URE/gen3.csv')
df1.drop(columns = 'Unnamed: 0',inplace = True, axis = 1)
df2 = pd.read_csv('/Users/vikramvelankar/Downloads/diabetes.csv')
df1,df2
# Out:
# (     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
#  0              3      117             62              0        0
#  1              4      100             50             20        0
#  2              5      139             70              0        0
#  3              8      144             70             27       32
#  4              5      130             68              0        0
#  ..           ...      ...            ...            ...      ...
#  263            6      130             70             24        0
#  264            0        0             76             30        0
#  265            4      136             64              0      121
#  266            4      128             64              0        0
#  267            5      128             66              0        0
#
#                BMI  DiabetesPedigreeFunction  Age  Outcome
#  0    3.123934e+01                  0.205000   26        1
# ...

# %%
df2 = df2[df2['Outcome'] == 1]

# %%
visualise_pca(df1)
# Out:
# <ScatterDensityAxes: >

# %%
visualise_pca(df2)
# Out:
# <ScatterDensityAxes: >

# %%
a = visualise_pca(df2, fake_dataset=df1)

# %%
a
# Out:
# <ScatterDensityAxes: >
